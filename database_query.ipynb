# %%
import json
import psycopg2
import pandas as pd
import geopandas as gpd

# %% [markdown]
# Establish data base connection

# %%
with open("/home/btphilip/notebooks/SQL_access.json") as f:
     db_conn_dict = json.load(f)

# %%
cred_string = 'postgresql://{user}:{password}@{host}:{port}/{database}'.format(**db_conn_dict)

# %%
conn = sqlalchemy.create_engine(cred_string)

# %% [markdown]
# Query database and display result

# %%
subset = pd.read_sql("select index, latitude, longitude from philip_ice_1 where latitude > 37.9", conn)

# %%
subset
# Out:
#     index   latitude   longitude
# 0       0  37.905610  107.707907
# 1       1  37.905610  107.707903
# 2       2  37.905609  107.707899
# 3       3  37.905608  107.707896
# 4       4  37.905607  107.707892
# 5       5  37.905607  107.707890
# 6       6  37.905607  107.707891
# 7       7  37.905606  107.707893
# 8       8  37.905606  107.707892
# 9       9  37.905606  107.707892
# 10     10  37.905606  107.707893
# 11     11  37.905607  107.707894
# 12     12  37.905608  107.707893
# 13     13  37.905608  107.707893
# 14     14  37.905609  107.707895
# 15     15  37.905610  107.707896
# 16     16  37.905609  107.707896
# 17     17  37.905611  107.707896
# 18     18  37.905611  107.707895
# 19     19  37.905611  107.707896
# 20     20  37.905611  107.707895
# 21     21  37.905610  107.707894
# 22     22  37.905611  107.707894
# 23     23  37.905612  107.707898
# 24     24  37.905611  107.707900
# 25     25  37.905610  107.707903
# 26     26  37.905608  107.707908
# ...

# %%
subset = gpd.read_sql("select index, latitude, longitude from philip_ice_1 where latitude > 37.9", conn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-baf3ba7612fe> in <module>()
# ----> 1 subset = gpd.read_sql("select index, latitude, longitude from philip_ice_1 where latitude > 37.9", conn)
#
# AttributeError: module 'geopandas' has no attribute 'read_sql'

# %%
subset = gpd.GeoDataFrame.from_postgis('select * from philip_ice_1', conn, geom_col = 'geom',crs = {'init':'epsg:4326'})

# %%
# %matplotlib notebook

# %%
type(subset)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
subset.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
subset.head()
# Out:
#    index        day.dec   latitude N/S   longitude E/W  GPSfix  NSats  HDOP  \
# 0      0  736382.673322  37.905610   N  107.707907   W       1      7  3.33
# 1      1  736382.673333  37.905610   N  107.707903   W       1      7  3.33
# 2      2  736382.673345  37.905609   N  107.707899   W       1      7  3.33
# 3      3  736382.673356  37.905608   N  107.707896   W       1      7  3.33
# 4      4  736382.673368  37.905607   N  107.707892   W       1      7  3.33
#
#    elevation                                         geom
# 0     3344.7           POINT (107.7079066666667 37.90561)
# 1     3344.1  POINT (107.7079026666667 37.90560983333334)
# 2     3343.6  POINT (107.7078988333333 37.90560883333333)
# 3     3343.3         POINT (107.7078963333333 37.9056085)
# 4     3342.7  POINT (107.7078916666667 37.90560716666667)
